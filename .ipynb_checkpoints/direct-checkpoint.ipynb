# %%
# !pip install nltk transformers torch scikit-learn rdflib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\ssanj\appdata\roaming\python\python313\site-packages (3.9.1)
# Requirement already satisfied: transformers in c:\users\ssanj\appdata\roaming\python\python313\site-packages (4.56.1)
# Requirement already satisfied: torch in c:\users\ssanj\appdata\roaming\python\python313\site-packages (2.8.0)
# Requirement already satisfied: scikit-learn in c:\users\ssanj\appdata\roaming\python\python313\site-packages (1.7.1)
# Requirement already satisfied: rdflib in c:\users\ssanj\appdata\roaming\python\python313\site-packages (7.1.4)
# Requirement already satisfied: click in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: filelock in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from rdflib) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssanj\appdata\roaming\python\python313\site-packages (from requests->transformers) (2025.7.9)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import re
import numpy as np
from rdflib import Graph, Namespace, RDF, Literal, URIRef, OWL
import logging
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModel
import torch
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("NLPMapper")

# Download nltk data if not already present
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Preprocessing utilities
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Load DeBERTa model
MODEL_NAME = "microsoft/deberta-v3-small"  # Change if needed
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)

# Use GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ssanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ssanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ssanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# C:\Users\ssanj\AppData\Roaming\Python\Python313\site-packages\transformers\convert_slow_tokenizer.py:564: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# DebertaV2Model(
#   (embeddings): DebertaV2Embeddings(
#     (word_embeddings): Embedding(128100, 768, padding_idx=0)
#     (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): DebertaV2Encoder(
#     (layer): ModuleList(
#       (0-5): 6 x DebertaV2Layer(
#         (attention): DebertaV2Attention(
#           (self): DisentangledSelfAttention(
#             (query_proj): Linear(in_features=768, out_features=768, bias=True)
#             (key_proj): Linear(in_features=768, out_features=768, bias=True)
#             (value_proj): Linear(in_features=768, out_features=768, bias=True)
#             (pos_dropout): Dropout(p=0.1, inplace=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): DebertaV2SelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): DebertaV2Intermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): DebertaV2Output(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (rel_embeddings): Embedding(512, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#   )
# )

# %%
def preprocess(text):
    text = re.sub(r'[_\-\.]', ' ', text.lower())
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(t) for t in tokens if t not in stop_words and len(t) > 2]
    return " ".join(tokens)

def get_embedding(text):
    if not text.strip():
        return np.zeros(model.config.hidden_size)
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
        last_hidden_state = outputs.last_hidden_state.squeeze(0)
        embedding = last_hidden_state.mean(dim=0).cpu().numpy()
    return embedding

# %%
def parse_json(json_file):
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    fields = set()
    def extract(obj, path=""):
        if isinstance(obj, dict):
            for k, v in obj.items():
                fields.add(k)
                if isinstance(v, (dict, list)):
                    extract(v, path + f".{k}" if path else k)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, path)
    extract(data)
    return list(fields)

def extract_value(data, field_name):
    if isinstance(data, dict):
        for k, v in data.items():
            if k == field_name:
                return v
            elif isinstance(v, (dict, list)):
                result = extract_value(v, field_name)
                if result is not None:
                    return result
    elif isinstance(data, list):
        for item in data:
            result = extract_value(item, field_name)
            if result is not None:
                return result
    return None

def parse_owl(owl_file):
    g = Graph()
    try:
        g.parse(owl_file, format="xml")
    except Exception:
        try:
            g.parse(owl_file, format="turtle")
        except Exception:
            g.parse(owl_file, format="json-ld")
    terms = {}
    for s, p, o in g.triples((None, RDF.type, OWL.Class)):
        terms[s.split("#")[-1]] = str(s)
    for s, p, o in g.triples((None, RDF.type, OWL.ObjectProperty)):
        terms[s.split("#")[-1]] = str(s)
    for s, p, o in g.triples((None, RDF.type, OWL.DatatypeProperty)):
        terms[s.split("#")[-1]] = str(s)
    logger.info(f"Extracted {len(terms)} terms from OWL.")
    return terms

# %%
def map_fields(json_fields, ontology_terms_dict, threshold=0.7):
    results = []
    ontology_embeddings = {}
    logger.info("Generating embeddings for ontology terms...")
    for term_name, uri in ontology_terms_dict.items():
        processed = preprocess(term_name)
        embedding = get_embedding(processed)
        ontology_embeddings[term_name] = (embedding, uri)

    logger.info("Mapping JSON fields to ontology terms...")
    for field in json_fields:
        processed_field = preprocess(field)
        field_vector = get_embedding(processed_field)
        best_match = None
        best_score = 0.0
        best_uri = None
        for term_name, (emb, uri) in ontology_embeddings.items():
            if np.any(field_vector) and np.any(emb):
                score = cosine_similarity(field_vector.reshape(1, -1), emb.reshape(1, -1))[0][0]
            else:
                score = 0.0
            if score > best_score:
                best_score = score
                best_match = term_name
                best_uri = uri
        results.append({
            "field": field,
            "match": best_match,
            "match_uri": best_uri,
            "score": best_score,
            "mapped": best_score >= threshold
        })
    return results

# %%
def generate_updated_owl(mapped_results, json_file, owl_file, output_file):
    """Update the OWL file by adding instances for mapped fields."""
    g = Graph()
    try:
        g.parse(owl_file, format="xml")
    except Exception:
        try:
            g.parse(owl_file, format="turtle")
        except Exception:
            g.parse(owl_file, format="json-ld")

    NS = Namespace("https://orbis-security.com/pe-malware-ontology#")
    g.bind("mapped", NS)
    g.bind("pe", NS)

    # Load JSON data
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    for idx, res in enumerate(mapped_results):
        term_uri = res["match_uri"]
        if not term_uri or not res["mapped"]:
            continue  # Skip unmapped or low-confidence fields

        term_ref = URIRef(term_uri)

        # Create a unique instance URI
        instance_uri = URIRef(f"{term_uri}_Instance{idx+1}")

        # Declare it as an instance of the ontology term
        g.add((instance_uri, RDF.type, term_ref))

        # Add additional properties
        g.add((instance_uri, NS.fieldName, Literal(res["field"])))
        g.add((instance_uri, NS.similarityScore, Literal(res["score"])))

        value = extract_value(data, res["field"])
        if value is not None:
            g.add((instance_uri, NS.fieldValue, Literal(str(value))))

    g.serialize(destination=output_file, format="xml")
    logger.info(f"Updated OWL with instances saved to {output_file}")

# %%
# File paths
json_file = "D:/study/nlp_mapping/00a35f1e23cef590bdfd8d2d30ecd7024b0028e34433384a840bf37638647af1.json"
owl_file = "D:/study/nlp_mapping/pe_malware_ontology.owl"
output_file = "D:/study/nlp_mapping/pe_malware_ontology_updated.owl"
threshold = 0.7

print("Parsing JSON file...")
json_fields = parse_json(json_file)

print("Parsing OWL file...")
ontology_terms_dict = parse_owl(owl_file)

print("Mapping fields...")
mapped_results = map_fields(json_fields, ontology_terms_dict, threshold)

for res in mapped_results:
    status = "✔" if res["mapped"] else "✘"
    print(f"{res['field']} → {res['match']} ({res['score']:.2f}) {status}")

print("Generating updated OWL file...")
generate_updated_owl(mapped_results, json_file, owl_file, output_file)

print(f"Finished! Updated OWL file saved as: {output_file}")
# Out:
# Parsing JSON file...
# INFO:NLPMapper:Extracted 209 terms from OWL.
# INFO:NLPMapper:Generating embeddings for ontology terms...
# Parsing OWL file...
# Mapping fields...
# INFO:NLPMapper:Mapping JSON fields to ontology terms...
# detections2pid → SetNetbiosName (0.97) ✔
# x86 → LockFile (0.97) ✔
# copy → Signature (0.99) ✔
# distributed → Executable (0.99) ✔
# read_files → section_name (0.98) ✔
# alert_log_full_path → url_strings_count (0.97) ✔
# pretty_return → has_file_feature (0.97) ✔
# cape_yara → SleepProcess (0.97) ✔
# curtain → Symbols (0.99) ✔
# dst → CLR (0.99) ✔
# http → TLS (0.97) ✔
# uri → CLR (0.97) ✔
# target → mz_count (0.99) ✔
# aux_signers → url_strings_count (0.96) ✔
# DynamicLoader → UnlockFile (0.99) ✔
# description → Symbols (0.97) ✔
# procdump → LockFile (0.99) ✔
# RegisteredOwner → ExecutableFile (0.98) ✔
# ep_bytes → mz_count (0.99) ✔
# license → Executable (0.99) ✔
# guest_signers → section_name (0.97) ✔
# rdata → PEFile (0.99) ✔
# processes → Action (0.99) ✔
# manager → Symbols (0.99) ✔
# pathtofile → WriteToFile (0.99) ✔
# raw_address → has_section_flag (0.99) ✔
# process_path → has_section_feature (0.98) ✔
# event → Resources (0.99) ✔
# started → Action (0.98) ✔
# sha512 → LockFile (0.98) ✔
# info → Symbols (0.99) ✔
# suricata → SleepProcess (0.96) ✔
# aux_sha1 → url_strings_count (0.95) ✔
# ra → None (0.00) ✘
# duration → Executable (0.99) ✔
# section → Section (1.00) ✔
# ssh → Debug (0.99) ✔
# dstport → CLR (0.97) ✔
# fileinfo → FileFeature (0.99) ✔
# options → Resources (0.99) ✔
# icon_fuzzy → section_entropy (0.98) ✔
# fingerprint → Symbols (0.99) ✔
# statistics → Symbols (0.99) ✔
# perf → Signature (0.99) ✔
# length → Executable (0.99) ✔
# eid → CLR (0.99) ✔
# offset → Debug (0.99) ✔
# executed_commands → ShutdownSystem (0.97) ✔
# tlsh → CLR (0.98) ✔
# aux_error_desc → url_strings_count (0.95) ✔
# time → mz_count (0.99) ✔
# actual_checksum → has_section_flag (0.97) ✔
# sublanguage → KillThread (0.97) ✔
# behavior → Executable (0.99) ✔
# characteristics → Readable (0.99) ✔
# http_method → has_section_feature (0.97) ✔
# dest_port → CodeSection (0.95) ✔
# parentcaller → UnloadDriver (0.99) ✔
# deduplicated_shots → AntiDebugging (0.96) ✔
# inaddrarpa → OpenSemaphore (0.96) ✔
# sha256 → LockFile (0.97) ✔
# timestamp → mz_count (0.99) ✔
# delete_files → DeleteFile (0.98) ✔
# write_keys → exports_count (0.98) ✔
# pcap_sha256 → SendDnsQuery (0.97) ✔
# pe → None (0.00) ✘
# pid → mz_count (0.99) ✔
# aux_valid → has_section_feature (0.97) ✔
# rrtype → FileFeature (0.98) ✔
# ssh_log_full_path → url_strings_count (0.98) ✔
# Process → Action (0.99) ✔
# tlp → CLR (0.99) ✔
# thread_id → Symbols (0.99) ✔
# moduleaddress → FileFeature (0.99) ✔
# shrike_msg → SleepProcess (0.97) ✔
# route → Relocations (0.99) ✔
# custom → Shareable (0.99) ✔
# alerts → Executable (0.99) ✔
# CommandLine → FileHandling (0.97) ✔
# mutexes → URLStrings (0.97) ✔
# summary → Symbols (0.98) ✔
# file_log_full_path → url_strings_count (0.97) ✔
# label → Symbols (0.99) ✔
# exports → Exports (1.00) ✔
# process_id → Action (0.99) ✔
# object → Symbols (0.99) ✔
# return → mz_count (0.99) ✔
# content → Resources (0.99) ✔
# domains → Executable (0.99) ✔
# iplookups → EnumerateThreads (0.98) ✔
# reporting → Action (0.99) ✔
# 3988 → CLR (0.94) ✔
# arguments → Signature (0.99) ✔
# src_port → has_section_flag (0.97) ✔
# MachineGUID → ReleaseMutex (0.98) ✔
# crc32 → CLR (0.98) ✔
# copyright → Writable (0.98) ✔
# http_log_full_path → url_strings_count (0.96) ✔
# ended → Executable (0.98) ✔
# procmemory → MountDisk (0.99) ✔
# path → mz_count (0.99) ✔
# anti_sandbox1 → url_strings_count (0.96) ✔
# shutdown_on → Executable (0.99) ✔
# osversion → CodeSection (0.96) ✔
# package → Resources (0.99) ✔
# repeated → Action (0.99) ✔
# category → Section (0.98) ✔
# created_services → has_section_feature (0.98) ✔
# overlay → Debug (0.99) ✔
# 00A35F1E23CEF590BDFD.exe → CLR (0.78) ✔
# T1116 → CLR (0.97) ✔
# SystemVolumeGUID → GetNetbiosName (0.97) ✔
# process → Action (0.99) ✔
# filetype → section_name (0.98) ✔
# timeout → Encrypt (0.98) ✔
# sha1 → PEFile (0.97) ✔
# debug → Debug (1.00) ✔
# type → Executable (0.99) ✔
# started_on → Action (0.98) ✔
# ttl → CLR (0.99) ✔
# weight → Executable (0.99) ✔
# sport → Action (0.99) ✔
# shrike_url → ReleaseMutex (0.97) ✔
# source_url → ExecutableFile (0.97) ✔
# status → mz_count (0.99) ✔
# shrike_sid → SleepProcess (0.97) ✔
# file → Resources (0.99) ✔
# version → Executable (0.99) ✔
# peb_parsing64 → OpenFileMapping (0.97) ✔
# imphash → PEFile (0.99) ✔
# grouped → Shareable (0.99) ✔
# T1057 → CLR (0.97) ✔
# dns_log_full_path → url_strings_count (0.98) ✔
# language → Executable (0.99) ✔
# payloads → Action (0.99) ✔
# WindowsPath → PathStrings (0.99) ✔
# qr → None (0.00) ✘
# virtual_address → has_section_flag (0.98) ✔
# ProductName → DownloadFile (0.98) ✔
# references → Shareable (0.99) ✔
# T1045 → CLR (0.97) ✔
# srcip → PEFile (0.98) ✔
# configs → section_name (0.98) ✔
# hostname → Executable (0.99) ✔
# serial → mz_count (0.99) ✔
# imagebase → UnlockFile (0.99) ✔
# dropped → Debug (0.98) ✔
# guest_paths → imports_count (0.98) ✔
# domainlookups → EnumerateThreads (0.98) ✔
# binary → Symbols (0.99) ✔
# resources → Resources (1.00) ✔
# processing → Resources (0.99) ✔
# RegisteredOrganization → ServiceHandling (0.98) ✔
# errors → Debug (0.99) ✔
# size → Executable (0.99) ✔
# tcp → Debug (0.99) ✔
# rcode → PEFile (0.99) ✔
# icon → Symbols (1.00) ✔
# shrike_refer → SystemManipulation (0.96) ✔
# imports → Debug (0.99) ✔
# log → mz_count (0.99) ✔
# irc → Exports (0.99) ✔
# calls → Action (0.98) ✔
# machine → Resources (0.99) ✔
# country_name → section_name (0.99) ✔
# strings → Signature (0.99) ✔
# eve_log_full_path → url_strings_count (0.96) ✔
# sha3_384 → CodeSection (0.96) ✔
# characteristics_raw → has_file_feature (0.97) ✔
# ssdeep → CLR (0.95) ✔
# reported_checksum → exports_count (0.98) ✔
# contenttype → FindFile (0.98) ✔
# families → Action (0.99) ✔
# encryptedbuffers → CreateFileMapping (0.98) ✔
# keys → mz_count (0.99) ✔
# subject → Section (0.99) ✔
# rd → None (0.00) ✘
# authenticode error → SendDnsQuery (0.97) ✔
# src_ip → TLS (0.99) ✔
# T1129 → CLR (0.96) ✔
# dport → PEFile (0.99) ✔
# event_type → section_name (0.99) ✔
# severity → Executable (0.99) ✔
# tls_log_full_path → url_strings_count (0.96) ✔
# entropy → Encrypt (0.99) ✔
# first_seen → section_name (0.96) ✔
# pdbpath → OpenFileMapping (0.98) ✔
# sni → CLR (0.99) ✔
# to → None (0.00) ✘
# entrypoint → CodeSection (0.98) ✔
# ua → None (0.00) ✘
# parent_id → Signature (0.99) ✔
# imported_dll_count → registry_strings_count (0.98) ✔
# srcport → LoadLibrary (0.98) ✔
# icmp → CLR (0.99) ✔
# dstip → CLR (0.97) ✔
# pretty_value → has_file_feature (0.97) ✔
# malscore → PathStrings (0.99) ✔
# Hit → Action (0.99) ✔
# name → Symbols (0.99) ✔
# resolved_apis → url_strings_count (0.96) ✔
# environ → Executable (0.99) ✔
# malfamily_tag → SectionFlag (0.97) ✔
# module_path → section_name (0.98) ✔
# network → Resources (0.99) ✔
# md5 → OpenEvent (0.97) ✔
# detections → Readable (0.99) ✔
# aux_timestamp → KillThread (0.98) ✔
# command → Action (0.99) ✔
# user_id → Signature (0.99) ✔
# ComputerName → ShowWindow (0.98) ✔
# author → Signature (0.99) ✔
# email → Executable (0.99) ✔
# CAPE → Exports (0.99) ✔
# caller → Signature (0.98) ✔
# smtp → Encrypt (0.99) ✔
# virtual_size → has_file_feature (0.98) ✔
# signatures → Signature (1.00) ✔
# module → Resources (0.99) ✔
# id → None (0.00) ✘
# UserName → Encrypt (0.98) ✔
# proto → Debug (0.99) ✔
# ja3 → PEFile (0.98) ✔
# flow_id → mz_count (0.99) ✔
# aux_error → has_section_feature (0.97) ✔
# ttps → CLR (0.97) ✔
# children → mz_count (0.99) ✔
# hosts → Exports (0.99) ✔
# write_files → section_name (0.98) ✔
# delete_keys → ShutdownSystem (0.98) ✔
# ikkzowxr.exe → ListenOnSocket (0.96) ✔
# data → Action (0.99) ✔
# dll → Debug (0.99) ✔
# process_name → has_file_feature (0.98) ✔
# value → Action (0.99) ✔
# addresses → Executable (0.99) ✔
# sections → Section (1.00) ✔
# flags → Symbols (1.00) ✔
# anomaly → Debug (0.99) ✔
# exported_dll_name → url_strings_count (0.98) ✔
# dest_ip → StopService (0.96) ✔
# rrname → PEFile (0.99) ✔
# tls → TLS (1.00) ✔
# peid_signatures → SleepProcess (0.97) ✔
# clamav → PEFile (0.97) ✔
# referrer → Writable (0.99) ✔
# read_keys → has_section_flag (0.97) ✔
# answers → Exports (0.98) ✔
# unknown section → has_section_flag (0.97) ✔
# size_of_data → has_file_feature (0.98) ✔
# cape_type → has_section_flag (0.97) ✔
# versioninfo → ResetEvent (0.98) ✔
# ip → None (0.00) ✘
# decrypt_config2 → GetFunctionAddress (0.97) ✔
# dirents → PEFile (0.98) ✔
# alert → Executable (0.99) ✔
# icon_hash → has_section_flag (0.99) ✔
# started_services → has_file_feature (0.98) ✔
# confidence → mz_count (0.99) ✔
# threads → Symbols (0.99) ✔
# tx_id → None (0.00) ✘
# parent_sample → has_section_flag (0.99) ✔
# SystemVolumeSerialNumber → ReadRegistryKeyValue (0.99) ✔
# api → Debug (0.99) ✔
# TempPath → PEFile (0.99) ✔
# A → None (0.00) ✘
# from → None (0.00) ✘
# files → Resources (0.99) ✔
# pcap_cnt → OpenFileMapping (0.96) ✔
# enhanced → Shareable (0.99) ✔
# udp → CLR (0.99) ✔
# regkey → PEFile (0.98) ✔
# cape_type_code → path_strings_count (0.98) ✔
# dead_hosts → exports_count (0.98) ✔
# meta → Exports (0.99) ✔
# new_data → has_file_feature (0.98) ✔
# digital_signers → section_name (0.97) ✔
# processtree → PEFile (0.99) ✔
# dns → mz_count (0.99) ✔
# src → TLS (0.99) ✔
# yara → CLR (0.98) ✔
# address → Executable (0.99) ✔
# static → Debug (0.99) ✔
# Generating updated OWL file...
# INFO:NLPMapper:Updated OWL file saved to D:/study/nlp_mapping/pe_malware_ontology_updated.owl
# Finished! Updated OWL file saved as: D:/study/nlp_mapping/pe_malware_ontology_updated.owl
